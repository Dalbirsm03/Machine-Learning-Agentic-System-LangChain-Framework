# %%
# Cell 1: Imports
from IPython.display import Image, display
import subprocess
from ML_AGENT.GRAPH.ML_Graph import Graph_Builder
from ML_AGENT.STATE.ML_state import State
from langchain_google_genai import ChatGoogleGenerativeAI
import os
os.environ['GOOGLE_API_KEY']="AIzaSyAdZtNIAuE_EtMaULXGeyAJGigSjpofaHk"

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# Build your graph
graph_builder = Graph_Builder(llm = llm).ml_graph__builder()

# Cell 2: Save Mermaid code to file and convert to PNG using mmdc
display(Image(graph_builder.get_graph().draw_mermaid_png()))

with open("temp_graph.mmd", "w") as f:
    f.write(mermaid_code)

# Run Mermaid CLI to create PNG
subprocess.run(["mmdc", "-i", "temp_graph.mmd", "-o", "temp_graph.png"])

# Cell 3: Display the PNG in the notebook
display(Image("temp_graph.png"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 22
#      19     f.write(mermaid_code)
#      21 # Run Mermaid CLI to create PNG
# ---> 22 subprocess.run(["mmdc", "-i", "temp_graph.mmd", "-o", "temp_graph.png"])
#      24 # Cell 3: Display the PNG in the notebook
#      25 display(Image("temp_graph.png"))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# ...
